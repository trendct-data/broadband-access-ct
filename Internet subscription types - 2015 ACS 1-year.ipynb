# %%
import pandas as pd

# %%
subscriptions = pd.read_csv("data/ACS_15_1YR_S2801/ACS_15_1YR_S2801_with_ann.csv",skiprows=1)

# %%
for c in subscriptions.columns:
    print c
# Out:
# Id
# Id2
# Geography
# Total; Estimate; Total households
# Total; Margin of Error; Total households
# Percent; Estimate; Total households
# Percent; Margin of Error; Total households
# Total; Estimate; TYPES OF COMPUTER - Has a computer
# Total; Margin of Error; TYPES OF COMPUTER - Has a computer
# Percent; Estimate; TYPES OF COMPUTER - Has a computer
# Percent; Margin of Error; TYPES OF COMPUTER - Has a computer
# Total; Estimate; TYPES OF COMPUTER - Has a computer - Desktop or laptop
# Total; Margin of Error; TYPES OF COMPUTER - Has a computer - Desktop or laptop
# Percent; Estimate; TYPES OF COMPUTER - Has a computer - Desktop or laptop
# Percent; Margin of Error; TYPES OF COMPUTER - Has a computer - Desktop or laptop
# Total; Estimate; TYPES OF COMPUTER - Has a computer - Desktop or laptop - Desktop or laptop alone
# Total; Margin of Error; TYPES OF COMPUTER - Has a computer - Desktop or laptop - Desktop or laptop alone
# ...

# %%
subscriptions[["Geography",
               "Total; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription:",
               "Total; Margin of Error; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription:",
               "Total; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription: - Without an Internet subscription",
               "Total; Margin of Error; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription: - Without an Internet subscription"]]
# Out:
#                                         Geography  \
# 0  Bridgeport town, Fairfield County, Connecticut
# 1     Danbury town, Fairfield County, Connecticut
# 2     Norwalk town, Fairfield County, Connecticut
# 3    Stamford town, Fairfield County, Connecticut
# 4     Hartford town, Hartford County, Connecticut
# 5  New Britain town, Hartford County, Connecticut
# 6   New Haven town, New Haven County, Connecticut
# 7   Waterbury town, New Haven County, Connecticut
#
#    Total; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription:  \
# 0                                              35281
# 1                                              24553
# 2                                              28487
# 3                                              41294
# 4                                              29235
# 5                                              19180
# 6                                              36239
# ...

# %%
subscriptions[["Geography",
               "Percent; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription:",
               "Percent; Margin of Error; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription:",
               "Percent; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription: - Without an Internet subscription",
               "Percent; Margin of Error; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription: - Without an Internet subscription"]]\
.sort_values(by="Percent; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription: - Without an Internet subscription",
            ascending=False)
# Out:
#                                         Geography  \
# 7   Waterbury town, New Haven County, Connecticut
# 4     Hartford town, Hartford County, Connecticut
# 5  New Britain town, Hartford County, Connecticut
# 0  Bridgeport town, Fairfield County, Connecticut
# 6   New Haven town, New Haven County, Connecticut
# 1     Danbury town, Fairfield County, Connecticut
# 3    Stamford town, Fairfield County, Connecticut
# 2     Norwalk town, Fairfield County, Connecticut
#
#    Percent; Estimate; TYPE OF INTERNET SUBSCRIPTIONS - With an Internet subscription:  \
# 7                                               65.0
# 4                                               65.2
# 5                                               68.9
# 0                                               70.8
# 6                                               74.4
# 1                                               82.5
# 3                                               87.4
# ...
