# %%
import pandas as pd, numpy as np

# %% [markdown]
# # FCC Internet Speed Data (Updated with 2016 data)
#
# Internet providers report speeds to the FCC via form 477.
#
# * Data: https://www.fcc.gov/general/broadband-deployment-data-fcc-form-477
# * Glossary: https://www.fcc.gov/general/explanation-broadband-deployment-data

# %% [markdown]
# # Part 0: Importing data

# %%
tracts = pd.read_csv("data/tracts_to_towns.csv")
tracts.head()
# Out:
#         tract       town
# 0  9001010101  Greenwich
# 1  9001010102  Greenwich
# 2  9001010201  Greenwich
# 3  9001010202  Greenwich
# 4  9001010300  Greenwich

# %%
providers = pd.read_excel("data/2016/Provider_List_Jun2016_v1.xlsx")
providers.head()
# Out:
#      FRN                          ProviderName StateAbbr  TechCode  records  \
# 0  10827                     Veracity Networks        UT        50     4008
# 1  12542                     SERVICE ONE CABLE        LA        42      726
# 2  12781                    NEU VENTURES, INC.        TX        41      921
# 3  12781                    NEU VENTURES, INC.        TX        70     1093
# 4  12849  MUTUAL COMMUNICATIONS SERVICES, INC.        IA        41       21
#
#    blocks
# 0    4008
# 1     726
# 2     921
# 3    1093
# 4      21

# %%
ct_speeds = pd.read_csv("data/2016/CT-Fixed-Jun2016-v1.csv")
print len(ct_speeds["BlockCode"].unique())
ct_speeds.head()
# Out:
# 65901
#    LogRecNo  Provider_Id      FRN                    ProviderName DBAName  \
# 0    234293        20901  4335584  MCI Communications Corporation     MCI
# 1    235491        20901  4335584  MCI Communications Corporation     MCI
# 2    235492        20901  4335584  MCI Communications Corporation     MCI
# 3    235493        20901  4335584  MCI Communications Corporation     MCI
# 4    235494        20901  4335584  MCI Communications Corporation     MCI
#
#             HoldingCompanyName  HocoNum                    HocoFinal  \
# 0  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 1  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 2  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 3  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 4  Verizon Communications Inc.   131425  Verizon Communications Inc.
#
#   StateAbbr       BlockCode  TechCode  Consumer  MaxAdDown  MaxAdUp  Business  \
# 0        CT  90010907002008        50         0        0.0      0.0         1
# 1        CT  90010101014013        30         0        0.0      0.0         1
# 2        CT  90010101023018        30         0        0.0      0.0         1
# 3        CT  90010102011024        30         0        0.0      0.0         1
# 4        CT  90010102023002        30         0        0.0      0.0         1
#
#    MaxCIRDown  MaxCIRUp
# 0        60.0      60.0
# 1         3.0       3.0
# 2         1.5       1.5
# 3         1.5       1.5
# 4         1.5       1.5

# %% [markdown]
# # Part 0-1: Joining data
#
# I'm going to add a town column to the ct_speeds dataframe, translating each tract to the town its a part of.

# %%
def list_of(x, n):
    return [x] * n

# Example usage 
print list_of(False, 5) + (list_of(False, 5))
print list_of(False, 10)
# Out:
# [False, False, False, False, False, False, False, False, False, False]
# [False, False, False, False, False, False, False, False, False, False]

# %%
# Clean town names
tracts["town"] = tracts.apply(lambda x: x["town"].title().strip(), axis=1)
tracts.head()
# Out:
#         tract       town
# 0  9001010101  Greenwich
# 1  9001010102  Greenwich
# 2  9001010201  Greenwich
# 3  9001010202  Greenwich
# 4  9001010300  Greenwich

# %%
# Add a column of census tracts, shorter than the block codes
def code_to_tract(code):
    sample_tract = "9001010101"
    tract_length = len(sample_tract)
    # return int(str(code)[:tract_length])
    return int('{0:d}'.format(int(code))[:tract_length])

code_to_tract(90117051013000)

ct_speeds["tract"] = ct_speeds.apply(lambda x: code_to_tract(x["BlockCode"]), axis=1)
ct_speeds.head()
# Out:
#    LogRecNo  Provider_Id      FRN                    ProviderName DBAName  \
# 0    234293        20901  4335584  MCI Communications Corporation     MCI
# 1    235491        20901  4335584  MCI Communications Corporation     MCI
# 2    235492        20901  4335584  MCI Communications Corporation     MCI
# 3    235493        20901  4335584  MCI Communications Corporation     MCI
# 4    235494        20901  4335584  MCI Communications Corporation     MCI
#
#             HoldingCompanyName  HocoNum                    HocoFinal  \
# 0  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 1  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 2  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 3  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 4  Verizon Communications Inc.   131425  Verizon Communications Inc.
#
#   StateAbbr       BlockCode  TechCode  Consumer  MaxAdDown  MaxAdUp  Business  \
# 0        CT  90010907002008        50         0        0.0      0.0         1
# 1        CT  90010101014013        30         0        0.0      0.0         1
# 2        CT  90010101023018        30         0        0.0      0.0         1
# 3        CT  90010102011024        30         0        0.0      0.0         1
# 4        CT  90010102023002        30         0        0.0      0.0         1
#
#    MaxCIRDown  MaxCIRUp       tract
# 0        60.0      60.0  9001090700
# 1         3.0       3.0  9001010101
# 2         1.5       1.5  9001010102
# 3         1.5       1.5  9001010201
# 4         1.5       1.5  9001010202

# %%
ct_speeds = ct_speeds.merge(tracts, left_on="tract", right_on="tract")
ct_speeds.head()
# Out:
#    LogRecNo  Provider_Id       FRN  \
# 0    234293        20901   4335584
# 1   2180866        21193   6275945
# 2   5778754        22328  18589226
# 3   5778755        22328  18589226
# 4   5778756        22328  18589226
#
#                                         ProviderName            DBAName  \
# 0                     MCI Communications Corporation                MCI
# 1                    XO Communications Services, LLC  XO Communications
# 2  Lightower Fiber Networks I, LLC (fka Light Tow...          Lightower
# 3  Lightower Fiber Networks I, LLC (fka Light Tow...          Lightower
# 4  Lightower Fiber Networks I, LLC (fka Light Tow...          Lightower
#
#             HoldingCompanyName  HocoNum                    HocoFinal  \
# 0  Verizon Communications Inc.   131425  Verizon Communications Inc.
# 1            XO Holdings, Inc.   131513            XO Holdings, Inc.
# 2       LTS Group Holdings LLC   131095       LTS Group Holdings LLC
# 3       LTS Group Holdings LLC   131095       LTS Group Holdings LLC
# 4       LTS Group Holdings LLC   131095       LTS Group Holdings LLC
#
#   StateAbbr       BlockCode  TechCode  Consumer  MaxAdDown  MaxAdUp  Business  \
# 0        CT  90010907002008        50         0        0.0      0.0         1
# 1        CT  90010907002008        30         0        0.0      0.0         1
# 2        CT  90010907001000        50         0        0.0      0.0         1
# 3        CT  90010907001001        50         0        0.0      0.0         1
# 4        CT  90010907001002        50         0        0.0      0.0         1
#
#    MaxCIRDown  MaxCIRUp       tract      town
# 0        60.0      60.0  9001090700  Trumbull
# 1        20.0      20.0  9001090700  Trumbull
# 2      1000.0    1000.0  9001090700  Trumbull
# 3      1000.0    1000.0  9001090700  Trumbull
# 4      1000.0    1000.0  9001090700  Trumbull

# %%
# checksum
print ct_speeds["town"].value_counts().sum()
print len(ct_speeds.index)
# Out:
# 464115
# 464115

# %% [markdown]
# # Part 3: Analysis

# %%
def gen_report(town_df):
    print "There are " + str(len(town_df["BlockCode"].unique())) + " census blocks and "\
    + str(len(town_df["tract"].unique())) + " tracts in __."
    print str(len(town_df["DBAName"].unique())) + " companies provide service."
    
    print "Advertised max speeds range from "\
    + str(town_df["MaxAdUp"].min()) + "/" + str(town_df["MaxAdDown"].min())\
    + " to "\
    + str(town_df["MaxAdUp"].max()) + "/" + str(town_df["MaxAdDown"].max())
    
    return town_df

def town_report(town_name):
    print "Generating report for " + town_name
    return gen_report(ct_speeds[ct_speeds["town"] == town_name.title()])

town_report("Greenwich").head()
# Out:
# Generating report for Greenwich
# There are 1242 census blocks and 15 tracts in __.
# 21 companies provide service.
# Advertised max speeds range from 0.0/0.0 to 100.0/115.0
#      LogRecNo  Provider_Id       FRN                         ProviderName  \
# 626    235491        20901   4335584       MCI Communications Corporation
# 627   3252080        21550  22757645  dishNET Satellite Broadband, L.L.C.
# 628   4844489        22266  19027440                     CSC Holdings LLC
# 629   4844490        22266  19027440                     CSC Holdings LLC
# 630   4844491        22266  19027440                     CSC Holdings LLC
#
#                              DBAName           HoldingCompanyName  HocoNum  \
# 626                              MCI  Verizon Communications Inc.   131425
# 627  dishNET Satellite Broadband LLC      dishNET Holding, L.L.C.   130627
# 628                       Altice USA            CSC Holdings, LLC   130370
# 629                       Altice USA            CSC Holdings, LLC   130370
# 630                       Altice USA            CSC Holdings, LLC   130370
#
#                        HocoFinal StateAbbr       BlockCode  TechCode  \
# 626  Verizon Communications Inc.        CT  90010101014013        30
# 627         dishNET Holding, LLC        CT  90010101013042        60
# 628                       Altice        CT  90010101011000        42
# 629                       Altice        CT  90010101011001        42
# 630                       Altice        CT  90010101011002        42
#
#      Consumer  MaxAdDown  MaxAdUp  Business  MaxCIRDown  MaxCIRUp       tract  \
# 626         0        0.0      0.0         1         3.0       3.0  9001010101
# 627         1       10.0      2.0         0         0.0       0.0  9001010101
# 628         1      101.0     35.0         1         0.0       0.0  9001010101
# 629         1      101.0     35.0         1         0.0       0.0  9001010101
# 630         1      101.0     35.0         1         0.0       0.0  9001010101
#
#           town
# 626  Greenwich
# 627  Greenwich
# 628  Greenwich
# 629  Greenwich
# 630  Greenwich

# %%
def summary_table(df, col):
    return ct_speeds.groupby(col)\
    .agg({
            "MaxAdDown":max,
            "MaxAdUp":max,
            "MaxCIRDown":max,
            "MaxCIRUp":max,
            "DBAName":lambda x: x.nunique(),
#             "BlockCode":lambda x: x.nunique(),   
         })\
    .reset_index()

town_speeds = summary_table(ct_speeds, "town")

town_speeds.head()
# Out:
#            town  DBAName  MaxAdDown  MaxAdUp  MaxCIRDown  MaxCIRUp
# 0       Ansonia       12      150.0     35.0      1000.0    1000.0
# 1       Ashford        8      115.0     12.0      1000.0    1000.0
# 2          Avon       14      150.0     12.0      1000.0    1000.0
# 3   Barkhamsted        9      115.0     12.0      1000.0    1000.0
# 4  Beacon Falls        8      150.0     12.0      1000.0    1000.0

# %% [markdown]
# #### Top business speeds: you can get 1 Gb everywhere
#
# Every town offers 1000 Mbps up/down for businesses.
#
# MaxCIRDown/Up - Maximum contractual downstream[/upstream] bandwidth offered by the provider in the block for Business service (filer directed to report 0 if the contracted service is sold on a "best efforts" basis without a guaranteed data-throughput rate)

# %%
town_speeds["MaxCIRUp"].value_counts()
# Out:
# 1000.0    167
# Name: MaxCIRUp, dtype: int64

# %%
town_speeds["MaxCIRDown"].value_counts()
# Out:
# 1000.0    167
# Name: MaxCIRDown, dtype: int64

# %% [markdown]
# #### Max advertised speed per town

# %%
town_speeds[["town","MaxAdUp","MaxAdDown"]].sort_values(by="MaxAdDown")
# Out:
#               town  MaxAdUp  MaxAdDown
# 122       Scotland      5.0      100.0
# 17        Brooklyn      5.0      100.0
# 21         Chaplin      5.0      100.0
# 43        Eastford      5.0      100.0
# 60         Hampton      5.0      100.0
# 65            Kent     35.0      101.0
# 52          Goshen     35.0      101.0
# 146         Warren     35.0      101.0
# 147     Washington     35.0      101.0
# 84          Morris     35.0      101.0
# 119        Roxbury     12.0      115.0
# 94      Newmilford     12.0      115.0
# 101        Norwalk     35.0      115.0
# 92     New Milford     12.0      115.0
# 87      New Canaan     35.0      115.0
# 32          Darien     35.0      115.0
# 165       Woodbury     35.0      115.0
# 81         Milford     35.0      115.0
# 26       Colebrook     12.0      115.0
# 44          Easton     35.0      115.0
# 126        Sherman     12.0      115.0
# 134       Stamford     35.0      115.0
# 54       Greenwich    100.0      115.0
# 14     Bridgewater     12.0      115.0
# 13      Bridgeport     35.0      115.0
# 142     Torrington     35.0      115.0
# 8        Bethlehem     35.0      115.0
# 48       Fairfield     35.0      115.0
# 154         Weston     35.0      115.0
# 155       Westport     35.0      115.0
# ..             ...      ...        ...
# 96         Norfolk     35.0      150.0
# 89    New Hartford     35.0      150.0
# 157     Willington     30.0      300.0
# 156   Wethersfield     30.0      300.0
# 59          Hamden     30.0      300.0
# 5           Berlin     30.0      300.0
# 93       Newington     30.0      300.0
# 162  Windsor Locks     30.0      300.0
# 42    East Windsor     30.0      300.0
# 45       Ellington     30.0      300.0
# 53          Granby     30.0      300.0
# 144         Vernon     30.0      300.0
# 62        Hartland     30.0      300.0
# 77         Meriden     30.0      300.0
# 74      Manchester     30.0      300.0
# 128         Somers     30.0      300.0
# 118     Rocky Hill     30.0      300.0
# 131    Southington     30.0      300.0
# 39   East Hartford     30.0      300.0
# 133       Stafford     30.0      300.0
# 22        Cheshire     30.0      300.0
# 114       Prospect     30.0      300.0
# 138       Suffield     30.0      300.0
# 86     New Britain     30.0      300.0
# 109     Plainville     30.0      300.0
# 145    Wallingford     30.0      300.0
# 36     East Granby     30.0      300.0
# 46         Enfield     30.0      300.0
# 51     Glastonbury   1000.0     1000.0
# 129  South Windsor   1000.0     1000.0
#
# [167 rows x 3 columns]

# %%
summary_table(ct_speeds[(ct_speeds["Consumer"] == 1)\
                       &(ct_speeds["MaxAdDown"] > 0)],
              "BlockCode")["MaxAdDown"].value_counts()
# Out:
# 150.0     22156
# 115.0      8716
# 101.0      7944
# 100.0      6912
# 15.0       6369
# 300.0      5529
# 24.0       4969
# 120.0      2603
# 110.0       526
# 0.0         103
# 12.0         33
# 6.0          20
# 1.0          10
# 55.0          5
# 1000.0        5
# 10.0          1
# Name: MaxAdDown, dtype: int64

# %%
town_speeds.sort_values(by="MaxAdDown")
# Out:
#               town  DBAName  MaxAdDown  MaxAdUp  MaxCIRDown  MaxCIRUp
# 122       Scotland        7      100.0      5.0      1000.0    1000.0
# 17        Brooklyn       10      100.0      5.0      1000.0    1000.0
# 21         Chaplin        9      100.0      5.0      1000.0    1000.0
# 43        Eastford        9      100.0      5.0      1000.0    1000.0
# 60         Hampton        8      100.0      5.0      1000.0    1000.0
# 65            Kent       11      101.0     35.0      1000.0    1000.0
# 52          Goshen        9      101.0     35.0      1000.0    1000.0
# 146         Warren        9      101.0     35.0      1000.0    1000.0
# 147     Washington       12      101.0     35.0      1000.0    1000.0
# 84          Morris        8      101.0     35.0      1000.0    1000.0
# 119        Roxbury        8      115.0     12.0      1000.0    1000.0
# 94      Newmilford       11      115.0     12.0      1000.0    1000.0
# 101        Norwalk       19      115.0     35.0      1000.0    1000.0
# 92     New Milford       12      115.0     12.0      1000.0    1000.0
# 87      New Canaan       15      115.0     35.0      1000.0    1000.0
# 32          Darien       15      115.0     35.0      1000.0    1000.0
# 165       Woodbury       10      115.0     35.0      1000.0    1000.0
# 81         Milford       18      115.0     35.0      1000.0    1000.0
# 26       Colebrook        8      115.0     12.0      1000.0    1000.0
# 44          Easton        8      115.0     35.0      1000.0    1000.0
# 126        Sherman        9      115.0     12.0      1000.0    1000.0
# 134       Stamford       22      115.0     35.0      1000.0    1000.0
# 54       Greenwich       21      115.0    100.0      1000.0    1000.0
# 14     Bridgewater        7      115.0     12.0      1000.0    1000.0
# 13      Bridgeport       19      115.0     35.0      1000.0    1000.0
# 142     Torrington       16      115.0     35.0      1000.0    1000.0
# 8        Bethlehem        9      115.0     35.0      1000.0    1000.0
# 48       Fairfield       17      115.0     35.0      1000.0    1000.0
# 154         Weston       11      115.0     35.0      1000.0    1000.0
# 155       Westport       20      115.0     35.0      1000.0    1000.0
# ..             ...      ...        ...      ...         ...       ...
# 96         Norfolk       10      150.0     35.0      1000.0    1000.0
# 89    New Hartford       12      150.0     35.0      1000.0    1000.0
# 157     Willington        9      300.0     30.0      1000.0    1000.0
# 156   Wethersfield       18      300.0     30.0      1000.0    1000.0
# 59          Hamden       20      300.0     30.0      1000.0    1000.0
# 5           Berlin       15      300.0     30.0      1000.0    1000.0
# 93       Newington       19      300.0     30.0      1000.0    1000.0
# 162  Windsor Locks       16      300.0     30.0      1000.0    1000.0
# 42    East Windsor       13      300.0     30.0      1000.0    1000.0
# 45       Ellington       14      300.0     30.0      1000.0    1000.0
# 53          Granby       13      300.0     30.0      1000.0    1000.0
# 144         Vernon       15      300.0     30.0      1000.0    1000.0
# 62        Hartland        8      300.0     30.0      1000.0    1000.0
# 77         Meriden       17      300.0     30.0      1000.0    1000.0
# 74      Manchester       18      300.0     30.0      1000.0    1000.0
# 128         Somers       17      300.0     30.0      1000.0    1000.0
# 118     Rocky Hill       16      300.0     30.0      1000.0    1000.0
# 131    Southington       16      300.0     30.0      1000.0    1000.0
# 39   East Hartford       16      300.0     30.0      1000.0    1000.0
# 133       Stafford       13      300.0     30.0      1000.0    1000.0
# 22        Cheshire       17      300.0     30.0      1000.0    1000.0
# 114       Prospect       12      300.0     30.0      1000.0    1000.0
# 138       Suffield        9      300.0     30.0      1000.0    1000.0
# 86     New Britain       16      300.0     30.0      1000.0    1000.0
# 109     Plainville       15      300.0     30.0      1000.0    1000.0
# 145    Wallingford       18      300.0     30.0      1000.0    1000.0
# 36     East Granby       15      300.0     30.0      1000.0    1000.0
# 46         Enfield       13      300.0     30.0      1000.0    1000.0
# 51     Glastonbury       17     1000.0   1000.0      1000.0    1000.0
# 129  South Windsor       16     1000.0   1000.0      1000.0    1000.0
#
# [167 rows x 6 columns]

# %% [markdown]
# #### How much "competition?"
#
# There were an average of 12 providers, with as many as 24 and as few as 7 providers in each CT town.

# %%
town_speeds["DBAName"].describe()
# Out:
# count    167.000000
# mean      12.766467
# std        3.646993
# min        7.000000
# 25%       10.000000
# 50%       12.000000
# 75%       16.000000
# max       22.000000
# Name: DBAName, dtype: float64

# %%
summary_table(ct_speeds, "tract")["DBAName"].describe()
# Out:
# count    829.000000
# mean      10.118215
# std        2.268354
# min        6.000000
# 25%        8.000000
# 50%       10.000000
# 75%       11.000000
# max       19.000000
# Name: DBAName, dtype: float64

# %% [markdown]
# #### Businesses have a lot of choices
# That's a surprisingly high number of providers, when I know that in practice it's nearly impossible as a consumer to get more than one company to provide internet access to an address, let alone 12. What if we exclude business providers?

# %%
summary_table(ct_speeds[ct_speeds["Consumer"] == 1], "BlockCode")["DBAName"].describe()
# Out:
# count    65901.000000
# mean         5.967451
# std          1.220557
# min          1.000000
# 25%          6.000000
# 50%          6.000000
# 75%          7.000000
# max         15.000000
# Name: DBAName, dtype: float64

# %% [markdown]
# #### Still higher than expected...
#
# I still didn't expect to see an average of 6 companies providing consumer internet acess in a given census block.
#
# Despite what the data has checked off, I don't believe these are all truly consumer ISPs. https://www.megapath.com/ describes itself as a business internet provider.

# %%
def list_providers(town_name):
    return ct_speeds[(ct_speeds["town"] == town_name.title())
                    & (ct_speeds["Consumer"] == 1)]["DBAName"].unique()

list_providers("Bethel")
# Out:
# array(['dishNET Satellite Broadband LLC', 'Comcast',
#        'Frontier Communications Corporation', 'Global Capacity LLC',
#        'ViaSat Inc', 'HughesNet', 'Skycasters',
#        'Charter Communications Inc', 'Altice USA'], dtype=object)

# %%
providers[providers["StateAbbr"] == "CT"]\
.drop_duplicates(subset=["ProviderName"]).sort_values(by="blocks", ascending=False)
# Out:
#            FRN                                       ProviderName StateAbbr  \
# 76     1568880                            GCI Communication Corp.        CT
# 5879  12369286                               HNS License Sub, LLC        CT
# 4263   4963088                                       ViaSat, Inc.        CT
# 7409  18756155                                  VSAT Systems, LLC        CT
# 1258   3576352                Frontier Communications Corporation        CT
# 2697   3768165                  COMCAST CABLE COMMUNICATIONS, LLC        CT
# 7131  18589226  Lightower Fiber Networks I, LLC (fka Light Tow...        CT
# 7528  19027440                                   CSC Holdings LLC        CT
# 2288   3746468                       Charter Communications, Inc.        CT
# 564    1834696                            Cox Communications, Inc        CT
# 6291  15336449                    Atlantic Broadband Finance, LLC        CT
# 5408   8797680                 Thames Valley Communications, Inc.        CT
# 5718  11017795                        PAETEC Communications, Inc.        CT
# 1204   3469442                              Verizon New York Inc.        CT
# 3669   4335584                     MCI Communications Corporation        CT
# 7898  20748331               GC Pivotal LLC d/b/a Global Capacity        CT
# 8365  22757645                dishNET Satellite Broadband, L.L.C.        CT
# 8278  22322481                       Cablevision Lightpath CT LLC        CT
# 1522   3720471                            EarthLink Business, LLC        CT
# 8954  25319039                                   GTT Americas LLC        CT
# 1828   3723822                       Level  3 Communications, LLC        CT
# 4762   6275945                    XO Communications Services, LLC        CT
# 5239   8307910                Advanced Corporate Networking, Inc.        CT
# 5512   9645201                       Universal Connectivity, Inc.        CT
# 1423   3716073      McLeodUSA Telecommunications Services, L.L.C.        CT
# 2531   3759602                         Birch Communications, Inc.        CT
# 3802   4339768                  Orange Business Services U.S. Inc        CT
# 6632  16555849                                    Zayo Group, LLC        CT
# 5156   8072803                  Reliance Globalcom Services, Inc.        CT
# 5185   8166795               New Horizon Communications Group Inc        CT
# 5601  10296853                  Broadview Networks Holdings, Inc.        CT
# 5084   7651219                   iLOKA Inc. dba NewCloud Networks        CT
# 7804  20419545                         S-Net Communications, Inc.        CT
# 8724  24167280                        WorxOne Communications, LLC        CT
# 8458  22976716                   NetFortris Acquisition Co., Inc.        CT
# 8132  21737515                                       APX Net, Inc        CT
# 2445   3755741                                     Call One, Inc.        CT
# 7487  18925107                      eVolve Business Solutions LLC        CT
# 7545  19066034                        Cogent Communications Group        CT
# 3513   4333845                                   Spectrotel, Inc.        CT
# 7030  18542233                     National Mobile Communications        CT
# 6461  16095432                               Believe Wireless LLC        CT
# 3856   4350930                             BullsEye Telecom, Inc.        CT
# 6193  14851448                                 VODA NETWORK, INC.        CT
# 7173  18602458                                   Access One, Inc.        CT
#
#       TechCode  records  blocks
# 76          60    64389   64389
# 5879        60    64389   64389
# 4263        60    64389   64389
# 7409        60    64389   64389
# 1258        10    49955   49955
# 2697        42    22940   22940
# 7131        50    20968   20968
# 7528        42    14217   14217
# 2288        42     9004    9004
# 564         42     5724    5724
# 6291        42     2612    2612
# 5408        40     1529    1529
# 5718        10     1151    1151
# 1204        10      578     578
# 3669        30      499     499
# 7898        10      471     471
# 8365        60      362     362
# 8278        50      330     330
# 1522        10      191     191
# 8954        10      128     128
# 1828        30      105     105
# 4762        30       92      92
# 5239        50       18      18
# 5512        50       12      12
# 1423        10       11      11
# 2531        30        5       5
# 3802        50        4       4
# 6632        50        2       2
# 5156        30        2       2
# 5185        10        2       2
# 5601        10        2       2
# 5084        30        1       1
# 7804        30        1       1
# 8724        10        1       1
# 8458        10        1       1
# 8132        30        1       1
# 2445        20        1       1
# 7487        30        1       1
# 7545        30        1       1
# 3513        10        1       1
# 7030        10        1       1
# 6461        70        1       1
# 3856        10        1       1
# 6193        10        1       1
# 7173        30        1       1

# %%
ct_consumer_speeds = ct_speeds[ct_speeds["Consumer"] == 1]

def dbas_in(provider_name, col="tract", df=ct_consumer_speeds):
    return ct_consumer_speeds[(df["DBAName"] == provider_name)]\
.drop_duplicates(subset=[col])

def count_in(provider_name,col="tract"):
    return len(dbas_in('Frontier Communications Corporation',
                       col=col)[col].index)


print count_in('Frontier Communications Corporation',"BlockCode")
print count_in('Frontier Communications Corporation',"tract")
print count_in('Frontier Communications Corporation',"town")
# Out:
# 53193
# 820
# 167

# %%
def test():
    ct_consumer_speeds = ct_speeds[ct_speeds["Consumer"] == 1]
    ct_non_consumer_speeds = ct_speeds[ct_speeds["Consumer"] == 0]
    
    print "Consumer records:" + str(len(ct_consumer_speeds.index))
    print "Non-consumer records:" + str(len(ct_non_consumer_speeds.index))
test()
# Out:
# Consumer records:373037
# Non-consumer records:91078

# %%
def blocks_in_state(dba):
    return ct_consumer_speeds[(ct_consumer_speeds["DBAName"] == dba)]

def blocks_in_town(dba):
    df = blocks_in_state(dba)
    return df[(df["town"] == 'Bethel')]

def tracts_in_state(dba):
    return blocks_in_state(dba).drop_duplicates(subset=["tract"])

def towns_in_state(dba):
    return blocks_in_state(dba).drop_duplicates(subset=["town"])

def max_upload(df):
    return df["MaxAdUp"].max()

def max_download(df):
    return df["MaxAdDown"].max()

def row_count(df):
    return len(df.index)

row_count(blocks_in_state('Charter Communications Inc'))
# Out:
# 9004

# %%
def all_providers ():
    provider_names = []
    provider_count_in_towns = []
    provider_count_in_blocks = []
    ret = []
    for dba in ct_consumer_speeds\
    .drop_duplicates(subset="DBAName")["DBAName"]:
        ret.append([
                dba,
                row_count(towns_in_state(dba)),
                row_count(tracts_in_state(dba)),
                row_count(blocks_in_state(dba)),
                max_upload(blocks_in_state(dba)),
                max_download(blocks_in_state(dba))
            ])
        
#         provider_names.append(dba)
#         provider_count_in_towns.append(count_in(dba, "town"))
#         provider_count_in_blocks.append(count_in(dba,"BlockCode"))
#     return [provider_names,provider_count_in_towns,provider_count_in_blocks]
    return pd.DataFrame(ret,columns=["Provider",
                                     "Consumer Towns",
                                     "Consumer Tracts",
                                     "Consumer Blocks",
                                    "Max Upstream",
                                    "Max Downstream"])

all_providers().sort_values(by="Consumer Blocks",
                           ascending=False)
# Out:
#                                Provider  Consumer Towns  Consumer Tracts  \
# 2   Frontier Communications Corporation             167              820
# 3                            ViaSat Inc             167              829
# 4                             HughesNet             167              829
# 5                            Skycasters             167              829
# 0                               Comcast             107              465
# 7                            Altice USA              49              236
# 1            Charter Communications Inc              68              125
# 11                   Cox Communications              28              117
# 13      Atlantic Broadband Finance, LLC              17               39
# 14         Thames Valley Communications               3               16
# 8                 Verizon New York Inc.               2               15
# 9                   Global Capacity LLC              39              207
# 6       dishNET Satellite Broadband LLC             130              238
# 10              Sovernet Communications               1                1
# 12                     NewCloudNetworks               1                1
# 15        eVolve Business Solutions LLC               1                1
#
#     Consumer Blocks  Max Upstream  Max Downstream
# 2            122906          30.0           115.0
# 3             64389           3.0            12.0
# 4             64389           2.0            15.0
# 5             64389           1.3             2.0
# 0             22197          10.0           150.0
# 7             14217          35.0           101.0
# 1              9004           5.0           100.0
# 11             5538        1000.0          1000.0
# 13             2612          10.0           120.0
# 14             1529          20.0           110.0
# 8              1055         100.0           100.0
# 9               447           1.0             8.0
# 6               362           2.0            15.0
# 10                1           1.0             1.0
# 12                1          10.0            10.0
# 15                1           3.0             3.0

# %%
ct_speeds[ct_speeds["DBAName"]=="Frontier Communications Corporation"]["MaxAdUp"].max()
ct_speeds[ct_speeds["DBAName"]=="Frontier Communications Corporation"]["MaxAdDown"].max()
# Out:
# 115.0

# %% [markdown]
# #### Differences by blocks and tracks

# %%
blocks = ct_speeds["BlockCode"].drop_duplicates().sort_values().to_frame()
tracts_data = ct_speeds["tract"].drop_duplicates().sort_values().to_frame()

# %%
def tract_df (tract):
    return ct_speeds[ct_speeds["tract"] == tract]
def block_df(block):
    return ct_speeds[ct_speeds["BlockCode"] == block]

def max_download_in_block(block):
    return max_download(block_df(block))

def max_download_in_tract(tract):
    return max_download(tract_df(tract))

# %%
tracts_data["MaxAdDown"] = tracts_data.apply(lambda x: max_download_in_tract(x["tract"]),axis=1)
tracts_data["MaxAdDown"].value_counts()
# Out:
# 150.0     438
# 115.0     203
# 300.0     115
# 120.0      34
# 101.0      22
# 100.0      14
# 1000.0      2
# 24.0        1
# Name: MaxAdDown, dtype: int64

# %%
blocks["MaxAdDown"] = blocks.apply(lambda x: max_download_in_block(x["BlockCode"]),axis=1)
blocks["MaxAdUp"] = blocks.apply(lambda x: max_download_in_block(x["BlockCode"]),axis=1)
blocks["MaxAdDown"].value_counts()
# Out:
# 150.0     22156
# 115.0      8716
# 101.0      7944
# 100.0      6912
# 15.0       6369
# 300.0      5529
# 24.0       4969
# 120.0      2603
# 110.0       526
# 0.0         103
# 12.0         33
# 6.0          20
# 1.0          10
# 55.0          5
# 1000.0        5
# 10.0          1
# Name: MaxAdDown, dtype: int64

# %%
row_count(blocks[blocks["MaxAdDown"] < 25])
# Out:
# 11505

# %%
row_count(blocks[blocks["MaxAdDown"] >= 25])
# Out:
# 54396

# %%
blocks.columns
# Out:
# Index([u'BlockCode', u'MaxAdDown', u'MaxAdUp'], dtype='object')

# %%
#blocks.apply(lambda x: "{0:d}".format(int(x["BlockCode"])),axis=1).to_frame()
blocks["tract"] = blocks.apply(lambda x: code_to_tract(x["BlockCode"]),axis=1).to_frame()
blocks.head()
# Out:
#           BlockCode  MaxAdDown  MaxAdUp       tract
# 628  90010101011000      101.0    101.0  9001010101
# 629  90010101011001      101.0    101.0  9001010101
# 630  90010101011002      101.0    101.0  9001010101
# 631  90010101011003      101.0    101.0  9001010101
# 632  90010101011004      101.0    101.0  9001010101

# %%
#blocks[blocks["MaxAdDown"] < 25].to_csv("output/slow_blocks.csv")

# %%
#tracts["town"] = tracts.apply(lambda x: x["town"].title().strip(), axis=1)

# %%
blocks = blocks.merge(tracts,left_on="tract",right_on="tract")
blocks.head()
# Out:
#         BlockCode  MaxAdDown  MaxAdUp       tract       town
# 0  90010101011000      101.0    101.0  9001010101  Greenwich
# 1  90010101011001      101.0    101.0  9001010101  Greenwich
# 2  90010101011002      101.0    101.0  9001010101  Greenwich
# 3  90010101011003      101.0    101.0  9001010101  Greenwich
# 4  90010101011004      101.0    101.0  9001010101  Greenwich

# %%
# Identify each town's percentage of slow blocks
# A slow block fails to meet the definition of broadband of 25 Mbps down / 3 up
def pct_slow(df):
    total_blocks = len((df["BlockCode"].unique()))
    #print "total blocks:", total_blocks
    tmpdf = df[(df["MaxAdUp"] > 0) | (df["MaxAdDown"] > 0)]
    tmpdf = tmpdf[(df["MaxAdUp"] < 3) | (df["MaxAdDown"] < 25)]
    slow_blocks = len(tmpdf.index)
    #print "slow_blocks",slow_blocks
    try:
        return [slow_blocks, total_blocks, slow_blocks * 100 / total_blocks]
    except:
        return [0,0,0]

def pct_slow_town(town_name):
    return pct_slow(blocks[blocks["town"] == town_name])

def slow_towns():
    ret = []
    for t in tracts["town"].unique():
        ret.append([t] + pct_slow_town(t))
    return pd.DataFrame(ret, columns=["town","slow blocks","total blocks","percent slow"])

print slow_towns()[["town","percent slow","slow blocks","total blocks"]]\
.sort_values(by="percent slow", ascending=False)\
.to_csv(sep="\t",index=False)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# town	percent slow	slow blocks	total blocks
# North Stonington	52	81	153
# Salisbury	47	140	292
# Hartland	47	45	94
# Chester	45	72	159
# East Granby	44	61	138
# Madison	44	213	478
# Sharon	44	114	255
# Norfolk	42	128	298
# Lyme	41	67	162
# Haddam	41	136	328
# Portland	40	95	234
# Preston	39	73	187
# Suffield	39	35	88
# Windsor Locks	39	111	283
# Windsor	38	188	489
# Salem	38	47	121
# Essex	38	65	171
# Stafford	38	181	465
# Cromwell	37	99	265
# Bloomfield	37	194	522
# East Hampton	36	99	274
# Bozrah	36	46	126
# Franklin	35	26	73
# Middlefield	34	80	229
# Colchester	34	115	329
# Middlebury	33	89	266
# Marlborough	33	53	157
# Rocky Hill	32	102	318
# Branford	32	171	522
# Beacon Falls	32	32	99
# Berlin	32	135	421
# Middletown	32	216	657
# New London	32	162	500
# East Haddam	31	109	342
# Farmington	31	136	435
# Glastonbury	30	185	601
# Avon	30	106	349
# Clinton	30	79	259
# Deep River	30	38	123
# North Canaan	29	35	119
# North Haven	29	147	505
# Durham	29	46	157
# Sterling	29	34	116
# Lisbon	28	30	106
# Simsbury	28	139	492
# Killingly	28	156	545
# Hartford	28	329	1150
# Old Lyme	28	41	142
# Burlington	28	51	176
# Waterford	28	147	513
# North Branford	27	79	290
# Guilford	27	124	446
# East Hartford	27	208	743
# Cheshire	27	122	449
# Prospect	26	32	123
# South Windsor	26	120	459
# Sprague	26	24	89
# East Lyme	26	139	519
# Old Saybrook	26	87	323
# Plainfield	26	103	385
# East Windsor	25	59	234
# Seymour	25	75	298
# Norwich	25	191	753
# Westbrook	25	61	238
# Enfield	25	67	266
# Bethany	25	33	130
# Southington	25	154	607
# Wallingford	25	179	711
# New Haven	24	366	1471
# Danbury	24	226	913
# Ridgefield	24	105	437
# Ledyard	24	127	510
# Ellington	24	72	298
# Bethel	23	65	271
# Tolland	23	67	291
# Killingworth	23	36	153
# Wethersfield	23	115	487
# Oldlyme	23	49	210
# Naugatuck	22	92	412
# Griswold	22	69	306
# Vernon	22	142	619
# Meriden	22	177	798
# New Britain	21	184	851
# Canton	20	41	202
# Somers	20	183	908
# Derby	20	40	196
# Bolton	19	16	82
# Manchester	19	176	901
# Waterbury	19	295	1490
# Montville	19	58	291
# Hebron	19	35	181
# Oxford	19	45	231
# Hamden	18	162	882
# East Haven	18	76	411
# West Hartford	18	162	893
# Granby	18	38	209
# Wolcott	17	43	252
# Plainville	17	56	323
# Newington	16	74	438
# Ansonia	15	45	286
# Shelton	15	84	546
# Putnam	14	42	281
# Plymouth	14	36	243
# Stonington	14	119	846
# West Haven	13	95	680
# Bristol	11	95	863
# Colebrook	10	11	103
# New Hartford	8	21	237
# Barkhamsted	8	15	186
# Ashford	7	15	205
# Thomaston	7	15	205
# Scotland	7	6	79
# Willington	6	11	161
# Groton	5	48	805
# Warren	4	6	121
# Kent	4	13	269
# Harwinton	4	9	193
# Thompson	3	12	385
# Lebanon	3	9	245
# Cornwall	3	9	246
# Brookfield	2	6	251
# Woodstock	2	7	323
# Canterbury	2	3	142
# Mansfield	2	11	408
# Winchester	2	6	297
# Eastford	2	3	131
# Hampton	1	2	124
# Trumbull	1	9	696
# Chaplin	1	2	127
# New Milford	1	7	593
# Woodbury	1	3	294
# Watertown	1	5	461
# Windham	1	5	461
# New Fairfield	1	3	250
# Litchfield	1	6	426
# Pomfret	1	3	171
# Redding	1	4	258
# Monroe	1	4	337
# Bridgewater	1	1	90
# Bethlehem	0	1	120
# Darien	0	1	474
# Newtown	0	3	615
# Columbia	0	1	105
# Brooklyn	0	0	177
# Coventry	0	2	280
# Stamford	0	5	1289
# Oldsaybrook	0	0	0
# Milford	0	3	1008
# Morris	0	0	142
# Southbury	0	2	368
# Easton	0	0	188
# Stratford	0	5	903
# Roxbury	0	1	117
# Washington	0	2	251
# Bridgeport	0	15	1713
# Sherman	0	1	117
# Fairfield	0	0	1162
# Torrington	0	0	728
# Orange	0	1	337
# Weston	0	0	207
# Woodbridge	0	1	207
# Newmilford	0	0	22
# Westport	0	4	628
# Wilton	0	0	387
# Norwalk	0	10	1267
# New Canaan	0	0	369
# Goshen	0	1	190
# Greenwich	0	9	1242

# %%
slow_pct_towns = slow_towns()[["town","percent slow","slow blocks","total blocks"]]
slow_pct_towns.sort_values("percent slow", ascending=False)
# Out:
# /usr/local/lib/python2.7/site-packages/ipykernel/__main__.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                  town  percent slow  slow blocks  total blocks
# 132  North Stonington            52           81           153
# 57          Salisbury            47          140           292
# 23           Hartland            47           45            94
# 87            Chester            45           72           159
# 35        East Granby            44           61           138
# 111           Madison            44          213           478
# 58             Sharon            44          114           255
# 78            Norfolk            42          128           298
# 121              Lyme            41           67           162
# 85             Haddam            41          136           328
# 82           Portland            40           95           234
# 128           Preston            39           73           187
# 40           Suffield            39           35            88
# 38      Windsor Locks            39          111           283
# 37            Windsor            38          188           489
# 139             Salem            38           47           121
# 90              Essex            38           65           171
# 152          Stafford            38          181           465
# 83           Cromwell            37           99           265
# 36         Bloomfield            37          194           522
# 81       East Hampton            36           99           274
# 137            Bozrah            36           46           126
# 136          Franklin            35           26            73
# 80        Middlefield            34           80           229
# 138        Colchester            34          115           329
# 114        Middlebury            33           89           266
# 52        Marlborough            33           53           157
# 44         Rocky Hill            32          102           318
# 108          Branford            32          171           522
# 112      Beacon Falls            32           32            99
# ..                ...           ...          ...           ...
# 53        Bridgewater             1            1            90
# 73          Bethlehem             0            1           120
# 2              Darien             0            1           474
# 19            Newtown             0            3           615
# 150          Columbia             0            1           105
# 164          Brooklyn             0            0           177
# 149          Coventry             0            2           280
# 1            Stamford             0            5          1289
# 142       Oldsaybrook             0            0             0
# 98            Milford             0            3          1008
# 69             Morris             0            0           142
# 118         Southbury             0            2           368
# 13             Easton             0            0           188
# 10          Stratford             0            5           903
# 63            Roxbury             0            1           117
# 62         Washington             0            2           251
# 9          Bridgeport             0           15          1713
# 22            Sherman             0            1           117
# 8           Fairfield             0            0          1162
# 71         Torrington             0            0           728
# 100            Orange             0            1           337
# 7              Weston             0            0           207
# 101        Woodbridge             0            1           207
# 55         Newmilford             0            0            22
# 6            Westport             0            4           628
# 5              Wilton             0            0           387
# 4             Norwalk             0           10          1267
# 3          New Canaan             0            0           369
# 66             Goshen             0            1           190
# 0           Greenwich             0            9          1242
#
# [168 rows x 4 columns]

# %%
print slow_pct_towns["total blocks"].sum()
print slow_pct_towns["slow blocks"].sum()
print slow_pct_towns["slow blocks"].sum() * 100 / slow_pct_towns["total blocks"].sum()
# Out:
# 65901
# 11402
# 17
